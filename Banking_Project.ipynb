# %%
data={}

# %% [markdown]
# # Register

# %%
def Register ():
    name=input('enter your name:')
    if name in data.keys():
        print('This user name is already register')
        Register()
    a=('1234567890')
    for i in range (1,4):
        phone=str(int(input('enter your phone number:')))
        if len(phone) == (len(a)):
            break
        else:
            print('Please enter vaild phone number')
            if i<3:
                print(f'{3-i} chance left')
            else:
                print('3 chance exceded')
                Register()
    for i in range(1,4):
        Email=input('enter your mail:')
        if Email.endswith('@gmail.com'):
            break
        else:
            print('please enter vaild mail id')
            if i<3:
                print(f'{3-i} chance only left')
            else:
                print('your 3 chance exit')
                Register()
    account_number=str(int(input('enter a\\c  number: ')))
    print('A\\C opening deposite amount above 1000 Rupees.')
    for i in range (1,4):
        balance=float(input('enter deposite amount:'))
        if balance>=1000:
            break
        else:
            print('deposite amount above 1000 Rupees.')
            if i<3:
                print(f'{3-i} chance left')
            else:
                print('3 chance exceeded please try again')
                Register()
    ATM_pin=str(int(input('enter ATM pin: ')))
    print('card type VIS or CC')
    card_Type=input('card type: ')
    data[name]={}
    data[name]['PI']={}
    data[name]['A\\C details']={}
    data[name]['PI']['name']=name
    data[name]['PI']['phone']=phone
    data[name]['PI']['Email']=Email
    data[name]['A\\C details']['account number']=account_number
    data[name]['A\\C details']['balance']=balance
    data[name]['A\\C details']['ATM pin']=ATM_pin
    data[name]['A\\C details']['card Type']=card_Type
    print (f'''
    ***********************************************
    * Hello {name}...                              *
    * WELCOME TO OUR BANK                         *
    * your A\C has been succussfully Registered   *
    ***********************************************''')
    for i in range (1,4):
        a=int(input('''
        Select any one option
        1.option
        2.Register
        3.exit'''))
        if a==1:
            option(name)
            break
        elif a==2:
            Register()
            break
        elif a==3:
            break
        else:
            print('Please select available option only')
            if i<3:
                print (f'{3-i} chance only left')
            else:
                print('3 chances exceded')
                Register()

# %% [markdown]
# # Main

# %%
def main(name):
    for i in range (1,4):
        a=int(input('''
        Select any one option
        1.option
        2.Register
        3.exit'''))
        if a==1:
            option(name)
            break
        elif a==2:
            Register()
            break
        elif a==3:
            break
        else:
            print('Please select available option only')
            if i<3:
                print (f'{3-i} chance only left')
            else:
                print('3 chances exceded')
                Register()

# %% [markdown]
# # Option

# %%
def option(name):
    for i in range (1,4):
        a=int(input('''
        Please select any one option
        1.ATM machin
        2.change of information
        3.view your personal information
        4.exit'''))
        if a == 1:
            ATM(name)
            
        elif a == 2:
            change(name)
            
        elif a == 3:
            view(name)
            
        elif a == 4:
            
            break
        else:
            print('Please select available option only')
            if i<3:
                print(f'{3-i} chance only left')
            else:
                print('3 chances exceded')
                main(name)

# %% [markdown]
# # Withdral

# %%
def withdral (name):
    print('''Please insert your card type
             card type VIA or CC''')
    a=input('card Type:')
    if a in data[name]['A\\C details']['card Type']:
        b=str(int(input('enter your pin number')))
        if b in data[name]['A\\C details']['ATM pin']:
            c=float(input('enter amount:'))
            if c <= data[name]['A\\C details']['balance']:
                print('Please collect your cash')
                d=data[name]['A\\C details']['balance']
                print (f'Available Balance:{d-c}')
                data[name]['A\\C details']['balance']=(f'{d-c}')
                option(name)
            else:
                print('Please chack your account balance. insufficient funds')
                ATM(name)
        else:
            print('Please enter correct Pin number')
            ATM(name)
    else:
        print('Please enter correct card type')
        ATM(name)

# %% [markdown]
# # ATM

# %%
def ATM(name):
    for i in range (1,4):
        a=int(input('''
        Please select any one option
        1.Cash withdral
        2.balance check
        3.cash deposite
        4.pin change
        5.exit'''))
        if a==1:
            withdral(name)
            break
        elif a==2:
            balance(name)
            break
        elif a==3:
            deposite(name)
            break
        elif a==4:
            change(name)
            break
        elif a==5:
            break
        else:
            print('Please select available option only')
            if i<3:
                print(f'{3-i} chance only left')
            else:
                print('3 chance exceded')
                option(name)

# %% [markdown]
# # Balance

# %%
def balance (name):
    print('''Please insert your card type
             card type VIA or CC''')
    a=input('card Type:')
    if a in data[name]['A\\C details']['card Type']:
        b=str(int(input('enter your pin number')))
        if b in data[name]['A\\C details']['ATM pin']:
            d=data[name]['A\\C details']['balance']
            print (f'Available Balance:{d}')
            ATM(name)
        else:
            print('Please enter correct Pin number')
            ATM(name)
    else:
        print('Please enter correct card type')
        ATM(name)

# %% [markdown]
# # Deposite

# %%
def deposite(name):
    print('''Please insert your card type
             card type VIA or CC''')
    a=input('card Type:')
    if a in data[name]['A\\C details']['card Type']:
        b=str(int(input('enter your pin number')))
        if b in data[name]['A\\C details']['ATM pin']:
            print('Please enter your cash deposite amount')
            c=float(input('enter your deposite amount:'))
            print('your cash deposite amount has been succussfully add in your account.')
            d=data[name]['A\\C details']['balance']
            print (f'Available Balance:{d+c}')
            ATM(name)
        else:
            print('Please enter correct Pin number')
            ATM(name)
    else:
        print('Please enter correct card type')
        ATM(name)

# %% [markdown]
# # View

# %%
def view(name):
    for i in range (1,4):
        a=int(input('''
        Please select any one option
        1.view your personal information
        2.view your account details
        3.complete full view 
        4.exit '''))
        if a == 1:
            b=data[name]['PI']
            for i,j in b.items():
                print(f'''{i}:{j}''')
            option(name)
        elif a == 2:
            c=data[name]['A\\C details']
            for i,j in c.items():
                print(f'''{i}:{j}''')
            option(name)
        elif a == 3:
            d=data[name]
            for i in d.keys():
                for k,l in data[name][i].items():
                    print(f'''{k}:{l}''')
            option(name)
        elif a == 4:
            break
        else:
            print('Please select available option only')
            if i<3:
                print(f'{3-i} chances only left')
            else:
                print('3 chance exceded')
                ATM(name)

# %% [markdown]
# # Change

# %%
def change(name):
    for i in range(1,4):
        a=int(input('''
        Please select any one option
        1.name change
        2.phone number change
        3.Email id change
        4.pin change
        5.exit'''))
        if a == 1:
            newname=input('enter newname:')
            data[newname]=data[name]
            data[newname]['PI']['name']=newname
            del data[name]
            print('name changed successfully')
            change(newname)
        elif a == 2:
            newnumber=str(int(input('newphone number ')))
            data[name]['PI']['phone']=newnumber
            print('phone changed successfully ')
            change(name)
        elif a == 3:
            newmail=input('new email id:')
            data[name]['PI']['Email']=newmail
            print('Email changed successfully ')
            change(name)
        elif a == 4:
            b=str(int(input('enter your old pin')))
            if b in data[name]['A\\C details']['ATM pin']:
                newpin=str(int(input('enter your new pin number')))
                data[name]['A\\C details']['ATM pin']=newpin
                print('pin changed successfully')
                change(name)
            else:
                print('Please enter correcct pin number')
                change(name)
        elif a == 5:
            break
        else:
            print('Please select available option only')
            if i<3:
                print(f'{3-i} chance only left')
            else:
                print(' 3 chance exceded')
                ATM(name)
